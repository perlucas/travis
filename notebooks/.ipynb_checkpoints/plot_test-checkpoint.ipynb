# %%
# !pip install pandas pandas-ta
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (2.1.1)
# Requirement already satisfied: pandas-ta in /opt/conda/lib/python3.11/site-packages (0.3.14b0)
# Requirement already satisfied: numpy>=1.23.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (1.24.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas_ta as ta
import numpy as np
import matplotlib.pyplot as plt

from utils import load_dataset

# %%
df = load_dataset('./PYPL.csv')

# %%
df
# Out:
#             Close    Volume   Open     High      Low
# Date
# 2023-08-14  63.27  22668030  62.15  63.4400  61.6800
# 2023-08-11  61.54  12419260  62.27  62.5000  61.4700
# 2023-08-10  62.79  13119080  62.60  63.0500  62.0750
# 2023-08-09  62.02  13788670  63.10  63.3900  61.9300
# 2023-08-08  63.19  17683730  63.77  63.9900  62.4900
# ...           ...       ...    ...      ...      ...
# 2015-07-10  34.69   4472801  34.66  35.1900  33.9805
# 2015-07-09  34.50   3760051  35.10  35.5199  33.9900
# 2015-07-08  34.70   5387318  36.34  36.3600  34.5300
# 2015-07-07  36.62   7356664  37.72  37.8100  36.0000
# 2015-07-06  36.71   5866447  38.00  39.7500  36.0000
#
# [2042 rows x 5 columns]

# %%
prices = df.loc[:, 'Close'].to_numpy()

# %%
df.ta.log_return(cumulative=True, append=True)
df.ta.percent_return(cumulative=True, append=True)
# Out:
# Date
# 2023-08-14    0.000000
# 2023-08-11   -0.027343
# 2023-08-10   -0.007587
# 2023-08-09   -0.019757
# 2023-08-08   -0.001264
#                 ...
# 2015-07-10   -0.451715
# 2015-07-09   -0.454718
# 2015-07-08   -0.451557
# 2015-07-07   -0.421211
# 2015-07-06   -0.419788
# Name: CUMPCTRET_1, Length: 2042, dtype: float64

# %%
rsi = df.ta.rsi().to_numpy()
rsi = np.where(np.isfinite(rsi), rsi, 0)
rsi = np.column_stack((rsi,))

# %%
ma1 = df.ta.sma(length=20).to_numpy()
ma1 = np.where(np.isfinite(ma1), ma1, 0)

ma2 = df.ta.sma(length=50).to_numpy()
ma2 = np.where(np.isfinite(ma2), ma2, 0)

ma3 = df.ta.sma(length=200).to_numpy()
ma3 = np.where(np.isfinite(ma3), ma3, 0)

# %%
frame_start = 100
frame_end = 600
prices = prices[frame_start:frame_end]
rsi = rsi[frame_start:frame_end]
ma1 = ma1[frame_start:frame_end]
ma2 = ma2[frame_start:frame_end]
ma3 = ma3[frame_start:frame_end]
prices.size
# Out:
# 500

# %%
plt.cla()
plt.figure(figsize=(20, 15))
plt.plot(prices)
#plt.plot(rsi)
plt.plot(ma1)
plt.plot(ma2)
plt.plot(ma3)

frames = range(0, prices.size, 20)
for x in frames:
    plt.axvline(x=x, color='gray')
#plt.show()
plt.savefig('./test.png')
